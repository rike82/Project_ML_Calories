# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fit = pd.read_excel('C:\\Users\\Rike\\Documents\\Ironhack\\MachineLearningW7\\fitness_data.xlsx')
# https://www.kaggle.com/datasets/arnavsmayan/fitness-tracker-dataset

# %%
df_fit.shape
# Out:
# (36500, 16)

# %%
df_fit.head(10)
# Out:
#    User_ID      Full Name       Date  Age  Gender  Height (cm)  Weight (kg)  \
# 0        1  Sara Martinez 2023-01-01   19  Female          191           80
# 1        1  Sara Martinez 2023-01-02   19  Female          191           80
# 2        1  Sara Martinez 2023-01-03   19  Female          191           80
# 3        1  Sara Martinez 2023-01-04   19  Female          191           80
# 4        1  Sara Martinez 2023-01-05   19  Female          191           80
# 5        1  Sara Martinez 2023-01-06   19  Female          191           80
# 6        1  Sara Martinez 2023-01-07   19  Female          191           80
# 7        1  Sara Martinez 2023-01-08   19  Female          191           80
# 8        1  Sara Martinez 2023-01-09   19  Female          191           80
# 9        1  Sara Martinez 2023-01-10   19  Female          191           80
#
#    Steps_Taken  Calories_Burned  Hours_Slept  Water_Intake (Liters)  \
# 0        11405             1862     7.021201               3.440508
# 1         7010             1806          NaN               3.103590
# 2        18942             2274     8.167817               3.814843
# 3        13778             2656     7.453552               3.508636
# 4        10247             3571     5.132654                    NaN
# 5         5081             2165          NaN               1.644844
# 6        12078             1756     8.983713               2.701125
# 7        18323             3167     6.925079               2.594056
# 8         2366             2344     5.007600               3.800947
# 9        11639             3283     8.619244               2.017812
#
#    Active_Minutes  Heart_Rate (bpm) Workout_Type  Stress_Level (1-10)  \
# 0            80.0              84.0         Yoga                    2
# 1            47.0              72.0       Cardio                    9
# 2            46.0              85.0         Yoga                    6
# 3           105.0              77.0         Yoga                    2
# 4            53.0              61.0         Yoga                    8
# 5            73.0              80.0         Yoga                   10
# 6            34.0              70.0       Cardio                    1
# 7           102.0              88.0         Yoga                    3
# 8             NaN              74.0       Cardio                    5
# 9           115.0              80.0         Yoga                    8
#
#        Mood
# 0     Happy
# 1   Neutral
# 2       Sad
# 3       Sad
# 4       Sad
# 5     Happy
# 6   Neutral
# 7   Neutral
# 8  Stressed
# 9   Neutral

# %%
df_fit.nunique()
# Out:
# User_ID                    100
# Full Name                   59
# Date                       365
# Age                         33
# Gender                       3
# Height (cm)                 36
# Weight (kg)                 40
# Steps_Taken              15614
# Calories_Burned           2500
# Hours_Slept              32841
# Water_Intake (Liters)    31099
# Active_Minutes              90
# Heart_Rate (bpm)            40
# Workout_Type                 4
# Stress_Level (1-10)         10
# Mood                         4
# dtype: int64

# %%
df_fit.isna().sum()
# Out:
# User_ID                     0
# Full Name                   0
# Date                        0
# Age                         0
# Gender                      0
# Height (cm)                 0
# Weight (kg)                 0
# Steps_Taken                 0
# Calories_Burned             0
# Hours_Slept              3659
# Water_Intake (Liters)    5401
# Active_Minutes           1867
# Heart_Rate (bpm)         1832
# Workout_Type                0
# Stress_Level (1-10)         0
# Mood                        0
# dtype: int64

# %%
df_fit.dropna(inplace= True)
df_fit
# Out:
#        User_ID      Full Name       Date  Age  Gender  Height (cm)  \
# 0            1  Sara Martinez 2023-01-01   19  Female          191
# 2            1  Sara Martinez 2023-01-03   19  Female          191
# 3            1  Sara Martinez 2023-01-04   19  Female          191
# 6            1  Sara Martinez 2023-01-07   19  Female          191
# 7            1  Sara Martinez 2023-01-08   19  Female          191
# ...        ...            ...        ...  ...     ...          ...
# 36493      100     Sara Jones 2023-12-25   54    Male          151
# 36494      100     Sara Jones 2023-12-26   54    Male          151
# 36497      100     Sara Jones 2023-12-29   54    Male          151
# 36498      100     Sara Jones 2023-12-30   54    Male          151
# 36499      100     Sara Jones 2023-12-31   54    Male          151
#
#        Weight (kg)  Steps_Taken  Calories_Burned  Hours_Slept  \
# 0               80        11405             1862     7.021201
# 2               80        18942             2274     8.167817
# 3               80        13778             2656     7.453552
# 6               80        12078             1756     8.983713
# 7               80        18323             3167     6.925079
# ...            ...          ...              ...          ...
# 36493          107        16593             1958     4.377548
# 36494          107         5875             3005     4.540873
# 36497          107        11892             2906     7.173268
# 36498          107        12967             1863     4.011179
# 36499          107        14667             2513     6.652888
#
#        Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm) Workout_Type  \
# 0                   3.440508            80.0              84.0         Yoga
# 2                   3.814843            46.0              85.0         Yoga
# 3                   3.508636           105.0              77.0         Yoga
# 6                   2.701125            34.0              70.0       Cardio
# 7                   2.594056           102.0              88.0         Yoga
# ...                      ...             ...               ...          ...
# 36493               2.683753            43.0              95.0         None
# 36494               2.188161            30.0              93.0         None
# 36497               3.237390            43.0              67.0       Cardio
# 36498               3.650197            85.0              61.0         Yoga
# 36499               3.199435           108.0              66.0         None
#
#        Stress_Level (1-10)     Mood
# 0                        2    Happy
# 2                        6      Sad
# 3                        2      Sad
# 6                        1  Neutral
# 7                        3  Neutral
# ...                    ...      ...
# 36493                    7  Neutral
# 36494                    8    Happy
# 36497                    9    Happy
# 36498                    4    Happy
# 36499                    8      Sad
#
# [25207 rows x 16 columns]

# %%
df_fit['Workout_Type'].unique()
# 1 cardio, 2 strength, 3 yoga, 4 none
# Out:
# array(['Yoga', 'Cardio', 'None', 'Strength'], dtype=object)

# %%
df_fit['Mood'].unique()  # 0 Stressed, 1 Sad, 2 Neutral, 3 Happy
# df_fit['Age'].unique()
# Out:
# array(['Happy', 'Sad', 'Neutral', 'Stressed'], dtype=object)

# %%
df_fit2 = df_fit.drop(columns=['Full Name','Date', 'User_ID'])
df_fit2.head()
# Out:
#    Age  Gender  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  \
# 0   19  Female          191           80        11405             1862
# 2   19  Female          191           80        18942             2274
# 3   19  Female          191           80        13778             2656
# 6   19  Female          191           80        12078             1756
# 7   19  Female          191           80        18323             3167
#
#    Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# 0     7.021201               3.440508            80.0              84.0
# 2     8.167817               3.814843            46.0              85.0
# 3     7.453552               3.508636           105.0              77.0
# 6     8.983713               2.701125            34.0              70.0
# 7     6.925079               2.594056           102.0              88.0
#
#   Workout_Type  Stress_Level (1-10)     Mood
# 0         Yoga                    2    Happy
# 2         Yoga                    6      Sad
# 3         Yoga                    2      Sad
# 6       Cardio                    1  Neutral
# 7         Yoga                    3  Neutral

# %%
df_fit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25207 entries, 0 to 36499
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    25207 non-null  int64
#  1   Gender                 25207 non-null  object
#  2   Height (cm)            25207 non-null  int64
#  3   Weight (kg)            25207 non-null  int64
#  4   Steps_Taken            25207 non-null  int64
#  5   Calories_Burned        25207 non-null  int64
#  6   Hours_Slept            25207 non-null  float64
#  7   Water_Intake (Liters)  25207 non-null  float64
#  8   Active_Minutes         25207 non-null  float64
#  9   Heart_Rate (bpm)       25207 non-null  float64
#  10  Workout_Type           25207 non-null  object
#  11  Stress_Level (1-10)    25207 non-null  int64
#  12  Mood                   25207 non-null  object
# dtypes: float64(4), int64(6), object(3)
# memory usage: 2.7+ MB

# %%
num_df = df_fit2.select_dtypes('number')
num_df
# Out:
#        Age  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  \
# 0       19          191           80        11405             1862
# 2       19          191           80        18942             2274
# 3       19          191           80        13778             2656
# 6       19          191           80        12078             1756
# 7       19          191           80        18323             3167
# ...    ...          ...          ...          ...              ...
# 36493   54          151          107        16593             1958
# 36494   54          151          107         5875             3005
# 36497   54          151          107        11892             2906
# 36498   54          151          107        12967             1863
# 36499   54          151          107        14667             2513
#
#        Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# 0         7.021201               3.440508            80.0              84.0
# 2         8.167817               3.814843            46.0              85.0
# 3         7.453552               3.508636           105.0              77.0
# 6         8.983713               2.701125            34.0              70.0
# 7         6.925079               2.594056           102.0              88.0
# ...            ...                    ...             ...               ...
# 36493     4.377548               2.683753            43.0              95.0
# 36494     4.540873               2.188161            30.0              93.0
# 36497     7.173268               3.237390            43.0              67.0
# 36498     4.011179               3.650197            85.0              61.0
# 36499     6.652888               3.199435           108.0              66.0
#
#        Stress_Level (1-10)
# 0                        2
# 2                        6
# 3                        2
# 6                        1
# 7                        3
# ...                    ...
# 36493                    7
# 36494                    8
# 36497                    9
# 36498                    4
# 36499                    8
#
# [25207 rows x 10 columns]

# %%
corr=np.abs(num_df.corr())

#Set up mask for triangle representation
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,  vmax=1,square=True, linewidths=.5, cbar_kws={"shrink": .5},annot = corr)

plt.show()

# %%
df_gender = pd.get_dummies(df_fit2['Gender'], dtype=int)
df_gender.head()
# Out:
#    Female  Male  Other
# 0       1     0      0
# 2       1     0      0
# 3       1     0      0
# 6       1     0      0
# 7       1     0      0

# %%
df_fit2.drop(columns= ['Gender'], inplace = True)
df_fit2
# Out:
#        Age  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  \
# 0       19          191           80        11405             1862
# 2       19          191           80        18942             2274
# 3       19          191           80        13778             2656
# 6       19          191           80        12078             1756
# 7       19          191           80        18323             3167
# ...    ...          ...          ...          ...              ...
# 36493   54          151          107        16593             1958
# 36494   54          151          107         5875             3005
# 36497   54          151          107        11892             2906
# 36498   54          151          107        12967             1863
# 36499   54          151          107        14667             2513
#
#        Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# 0         7.021201               3.440508            80.0              84.0
# 2         8.167817               3.814843            46.0              85.0
# 3         7.453552               3.508636           105.0              77.0
# 6         8.983713               2.701125            34.0              70.0
# 7         6.925079               2.594056           102.0              88.0
# ...            ...                    ...             ...               ...
# 36493     4.377548               2.683753            43.0              95.0
# 36494     4.540873               2.188161            30.0              93.0
# 36497     7.173268               3.237390            43.0              67.0
# 36498     4.011179               3.650197            85.0              61.0
# 36499     6.652888               3.199435           108.0              66.0
#
#       Workout_Type  Stress_Level (1-10)     Mood
# 0             Yoga                    2    Happy
# 2             Yoga                    6      Sad
# 3             Yoga                    2      Sad
# 6           Cardio                    1  Neutral
# 7             Yoga                    3  Neutral
# ...            ...                  ...      ...
# 36493         None                    7  Neutral
# 36494         None                    8    Happy
# 36497       Cardio                    9    Happy
# 36498         Yoga                    4    Happy
# 36499         None                    8      Sad
#
# [25207 rows x 12 columns]

# %%
target = df_fit2['Calories_Burned']

# %%
workout_order = ['None', 'Yoga', 'Strength', 'Cardio']  # Rangfolge

# Konvertiere die Workout_Type-Spalte in eine ordinale Variable
df_fit2['Workout_Type'] = pd.Categorical(df_fit2['Workout_Type'], categories=workout_order, ordered=True)
df_fit2['Workout_Type'] = df_fit2['Workout_Type'].cat.codes    
df_fit2.head()
# Out:
#    Age  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  Hours_Slept  \
# 0   19          191           80        11405             1862     7.021201
# 2   19          191           80        18942             2274     8.167817
# 3   19          191           80        13778             2656     7.453552
# 6   19          191           80        12078             1756     8.983713
# 7   19          191           80        18323             3167     6.925079
#
#    Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  Workout_Type  \
# 0               3.440508            80.0              84.0             1
# 2               3.814843            46.0              85.0             1
# 3               3.508636           105.0              77.0             1
# 6               2.701125            34.0              70.0             3
# 7               2.594056           102.0              88.0             1
#
#    Stress_Level (1-10)     Mood
# 0                    2    Happy
# 2                    6      Sad
# 3                    2      Sad
# 6                    1  Neutral
# 7                    3  Neutral

# %%
mood_order = ['Happy', 'Neutral', 'Sad', 'Stressed']
df_fit2['Mood'] = pd.Categorical(df_fit2['Mood'], categories= mood_order, ordered=True)
df_fit2['Mood'] = df_fit2['Mood'].cat.codes    
df_fit2
# Out:
#        Age  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  \
# 0       19          191           80        11405             1862
# 2       19          191           80        18942             2274
# 3       19          191           80        13778             2656
# 6       19          191           80        12078             1756
# 7       19          191           80        18323             3167
# ...    ...          ...          ...          ...              ...
# 36493   54          151          107        16593             1958
# 36494   54          151          107         5875             3005
# 36497   54          151          107        11892             2906
# 36498   54          151          107        12967             1863
# 36499   54          151          107        14667             2513
#
#        Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# 0         7.021201               3.440508            80.0              84.0
# 2         8.167817               3.814843            46.0              85.0
# 3         7.453552               3.508636           105.0              77.0
# 6         8.983713               2.701125            34.0              70.0
# 7         6.925079               2.594056           102.0              88.0
# ...            ...                    ...             ...               ...
# 36493     4.377548               2.683753            43.0              95.0
# 36494     4.540873               2.188161            30.0              93.0
# 36497     7.173268               3.237390            43.0              67.0
# 36498     4.011179               3.650197            85.0              61.0
# 36499     6.652888               3.199435           108.0              66.0
#
#        Workout_Type  Stress_Level (1-10)  Mood
# 0                 1                    2     0
# 2                 1                    6     2
# 3                 1                    2     2
# 6                 3                    1     1
# 7                 1                    3     1
# ...             ...                  ...   ...
# 36493             0                    7     1
# 36494             0                    8     0
# 36497             3                    9     0
# 36498             1                    4     0
# 36499             0                    8     2
#
# [25207 rows x 12 columns]

# %%
df_fit_final = pd.concat([df_fit2, df_gender], axis=1)
df_fit_final
# Out:
#        Age  Height (cm)  Weight (kg)  Steps_Taken  Calories_Burned  \
# 0       19          191           80        11405             1862
# 2       19          191           80        18942             2274
# 3       19          191           80        13778             2656
# 6       19          191           80        12078             1756
# 7       19          191           80        18323             3167
# ...    ...          ...          ...          ...              ...
# 36493   54          151          107        16593             1958
# 36494   54          151          107         5875             3005
# 36497   54          151          107        11892             2906
# 36498   54          151          107        12967             1863
# 36499   54          151          107        14667             2513
#
#        Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# 0         7.021201               3.440508            80.0              84.0
# 2         8.167817               3.814843            46.0              85.0
# 3         7.453552               3.508636           105.0              77.0
# 6         8.983713               2.701125            34.0              70.0
# 7         6.925079               2.594056           102.0              88.0
# ...            ...                    ...             ...               ...
# 36493     4.377548               2.683753            43.0              95.0
# 36494     4.540873               2.188161            30.0              93.0
# 36497     7.173268               3.237390            43.0              67.0
# 36498     4.011179               3.650197            85.0              61.0
# 36499     6.652888               3.199435           108.0              66.0
#
#        Workout_Type  Stress_Level (1-10)  Mood  Female  Male  Other
# 0                 1                    2     0       1     0      0
# 2                 1                    6     2       1     0      0
# 3                 1                    2     2       1     0      0
# 6                 3                    1     1       1     0      0
# 7                 1                    3     1       1     0      0
# ...             ...                  ...   ...     ...   ...    ...
# 36493             0                    7     1       0     1      0
# 36494             0                    8     0       0     1      0
# 36497             3                    9     0       0     1      0
# 36498             1                    4     0       0     1      0
# 36499             0                    8     2       0     1      0
#
# [25207 rows x 15 columns]

# %%
features = df_fit_final.drop(columns = ["Calories_Burned"])

# %%
target_2 = df_fit_final['Calories_Burned']

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(features, target_2, test_size=0.20, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.predict(X_test_scaled)
# Out:
# C:\Users\Rike\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([2567.6, 2567.6, 2567.6, ..., 2567.6, 2567.6, 2567.6])

# %%
y_test
# Out:
# 26357    3488
# 7119     1812
# 22029    2941
# 12805    2886
# 26463    3453
#          ...
# 2548     1892
# 2579     1687
# 18871    3314
# 3437     1854
# 6554     2600
# Name: Calories_Burned, Length: 5042, dtype: int64

# %%
knn.score(X_test, y_test) # score = accuracy
# Out:
# -0.2052947717926803

# %%
# tsten in zwei notebooks für workout type ordinal or nominal
# heatmap for stress and mood

# %%
from sklearn.linear_model import LinearRegression

# %%
len_reg = LinearRegression()

# %%
len_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
len_reg.score(X_test,y_test)
# Out:
# -0.0006694169706678021

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor(max_depth = 3)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
tree.score(X_test,y_test)
# Out:
# -0.0025801973606343065
